# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install statistics
# !pip install os_sys
# Out:
# Requirement already satisfied: pandas in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: statistics in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (1.0.3.5)
# Requirement already satisfied: docutils>=0.3 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from statistics) (0.19)
# Collecting os_sys
#   Using cached os_sys-2.1.4-py3-none-any.whl (15.6 MB)
# Collecting pygubu
#   Using cached pygubu-0.27-py3-none-any.whl (112 kB)
# Requirement already satisfied: pytz in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from os_sys) (2022.6)
# Collecting sqlparse
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# Collecting progress
#   Using cached progress-1.6.tar.gz (7.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting progressbar
#   Using cached progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from os_sys) (3.6.2)
# Requirement already satisfied: numpy in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from os_sys) (1.23.5)
# Requirement already satisfied: six in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from os_sys) (1.16.0)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: pandas in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from os_sys) (1.5.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\basti\appdata\local\programs\python\python311\lib\site-packages (from os_sys) (4.11.1)
# Collecting Eel
#   Using cached Eel-0.15.0.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting extract-zip
#   Using cached extract_zip-1.0.0-py3-none-any.whl (2.6 kB)
# Collecting os_sys
#   Using cached os_sys-2.1.3-py3-none-any.whl (15.5 MB)
#   Using cached os_sys-2.1.2-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.1.1-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.1.0-py3-none-any.whl (15.9 MB)
#   Using cached os_sys-2.0.9-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.0.8-py3-none-any.whl (15.4 MB)
#   Using cached os_sys-2.0.7-py3-none-any.whl (14.2 MB)
#   Using cached os_sys-2.0.6-py3-none-any.whl (14.2 MB)
#   Using cached os_sys-2.0.5-py3-none-any.whl (12.2 MB)
#   Using cached os_sys-2.0.4-py3-none-any.whl (50.9 MB)
# Collecting webview
#   Using cached webview-0.1.5.tar.gz (18 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting os_sys
#   Using cached os_sys-2.0.3-py3-none-any.whl (51.8 MB)
#   Using cached os_sys-2.0.2-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-2.0.1-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-2.0.0-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.9-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.8-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.7-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.6-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.5-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.4-py3-none-any.whl (54.1 MB)
#   Using cached os_sys-1.9.3-py3-none-any.whl (60.4 MB)
# ERROR: os-sys has an invalid wheel, os-sys has an invalid wheel, could not read 'os_sys-1.9.3.dist-info/WHEEL' file: KeyError("There is no item named 'os_sys-1.9.3.dist-info/WHEEL' in the archive")

# %% [markdown]
#  ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from random import randrange
import statistics  as sts


pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Import Data
# Change datatype to float and replace commata with dots

# %%
df = pd.read_csv("Covid.csv")
df.columns = ["Id","Country","TotalCases","TotalDeaths","NewDeaths","TotalRecovered","ActiveCases","SeriousCritical","TotCases1Mpop","Deaths1Mpop","TotalTests","Tests1Mpop","Population"]
df = df.set_index("Id")

df.dtypes
col = df.select_dtypes(include = "object").columns
col = col[ col != 'Country']


df['TotalCases'] = df['TotalCases'].str.replace(",", "").astype(float)
df['SeriousCritical'] = df['SeriousCritical'].str.replace(",", "").astype(float)
df['Tests1Mpop'] = df['Tests1Mpop'].str.replace(",", "").astype(float)
df[ 'TotalDeaths'] = df[ 'TotalDeaths'].str.replace(",", "").astype(float)
df[ 'TotCases1Mpop'] = df[ 'TotCases1Mpop'].str.replace(",", "").astype(float)
df[ 'Population'] = df[ 'Population'].str.replace(",", "").astype(float)
df[ 'TotalRecovered'] = df[ 'TotalRecovered'].str.replace(",", "").astype(float)
df[ 'Deaths1Mpop'] = df[ 'Deaths1Mpop'].str.replace(",", "").astype(float)
df[ 'ActiveCases'] = df[ 'ActiveCases'].str.replace(",", "").astype(float)
df[ 'TotalTests'] = df[ 'TotalTests'].str.replace(",", "").astype(float)

columns = df.columns
columns = list(columns)

# %% [markdown]
# # First Look at data

# %%
df.head()
# Out:
#     Country   TotalCases  TotalDeaths  NewDeaths  TotalRecovered  ActiveCases  \
# Id
# 1       USA 98166904.000  1084282.000        NaN    94962112.000  2120510.000
# 2     India 44587307.000   528629.000        NaN    44019095.000    39583.000
# 3    France 35342950.000   155078.000        NaN    34527115.000   660757.000
# 4    Brazil 34706757.000   686027.000        NaN    33838636.000   182094.000
# 5   Germany 33312373.000   149948.000        NaN    32315200.000   847225.000
#
#     SeriousCritical  TotCases1Mpop  Deaths1Mpop     TotalTests  Tests1Mpop  \
# Id
# 1          2970.000     293206.000     3239.000 1118158870.000 3339729.000
# 2           698.000      31698.000      376.000  894416853.000  635857.000
# 3           869.000     538892.000     2365.000  271490188.000 4139547.000
# 4          8318.000     161162.000     3186.000   63776166.000  296146.000
# 5          1406.000     397126.000     1788.000  122332384.000 1458359.000
#
#        Population
# Id
# 1   334805269.000
# 2  1406631776.000
# 3    65584518.000
# 4   215353593.000
# 5    83883596.000

# %%
df.isnull().sum()
# Out:
# Country              0
# TotalCases           0
# TotalDeaths          5
# NewDeaths          227
# TotalRecovered      16
# ActiveCases         15
# SeriousCritical     83
# TotCases1Mpop        2
# Deaths1Mpop          7
# TotalTests          16
# Tests1Mpop          16
# Population           2
# dtype: int64

# %%
df['NewDeaths'].fillna(0, inplace=True)
df['TotalDeaths'].fillna(sts.mean(df['TotalDeaths'].dropna()), inplace=True)
df['TotalRecovered'].fillna(sts.mean(df['TotalRecovered'].dropna()), inplace=True)
df['ActiveCases'].fillna(sts.mean(df['ActiveCases'].dropna()), inplace=True)
df['SeriousCritical'].fillna(sts.mean(df['SeriousCritical'].dropna()), inplace=True)
df['TotCases1Mpop'].fillna(sts.mean(df['TotCases1Mpop'].dropna()), inplace=True)
df['Deaths1Mpop'].fillna(sts.mean(df['Deaths1Mpop'].dropna()), inplace=True)
df['TotalTests'].fillna(sts.mean(df['TotalTests'].dropna()), inplace=True)
df['Tests1Mpop'].fillna(sts.mean(df['Tests1Mpop'].dropna()), inplace=True)
df['Population'].fillna(sts.mean(df['Population'].dropna()), inplace=True)

# %%
df.isnull().sum()
# Out:
# Country            0
# TotalCases         0
# TotalDeaths        0
# NewDeaths          0
# TotalRecovered     0
# ActiveCases        0
# SeriousCritical    0
# TotCases1Mpop      0
# Deaths1Mpop        0
# TotalTests         0
# Tests1Mpop         0
# Population         0
# dtype: int64

# %% [markdown]
# # Simple Plottting to see Relations

# %%
sns.scatterplot(data= df, y = "Deaths1Mpop", x="TotCases1Mpop")
# Out:
# <AxesSubplot: xlabel='TotCases1Mpop', ylabel='Deaths1Mpop'>

# %%
sns.scatterplot(data= df, x = "TotCases1Mpop", y="SeriousCritical")
# Out:
# <AxesSubplot: xlabel='TotCases1Mpop', ylabel='SeriousCritical'>

# %%
sns.scatterplot(data= df, x = "TotalCases", y="TotalRecovered")
# Out:
# <AxesSubplot: xlabel='TotalCases', ylabel='TotalRecovered'>

# %%
PossibleXColums = ["TotalCases","TotalDeaths","NewDeaths","TotalRecovered","ActiveCases","SeriousCritical","TotCases1Mpop","Deaths1Mpop","TotalTests","Tests1Mpop","Population"]
PossibleYColums = ["TotalCases","TotalDeaths","NewDeaths","TotalRecovered","ActiveCases","SeriousCritical","TotCases1Mpop","Deaths1Mpop","TotalTests","Tests1Mpop","Population"]

for i in range(10):
    sns.relplot(data=df, x = PossibleXColums[randrange(10)], y = PossibleYColums[randrange(10)], kind="scatter")

# %%
PossibleColums = ["TotalCases","TotalDeaths","NewDeaths","TotalRecovered","ActiveCases","SeriousCritical","TotCases1Mpop","Deaths1Mpop","TotalTests","Tests1Mpop","Population"]

xe = PossibleColums[randrange(10)]
ye = PossibleColums[randrange(10)]

for i in range(10):
    xe = PossibleColums[randrange(10)]
    ye = PossibleColums[randrange(10)]
    if xe == ye:
        xe = PossibleColums[randrange(10)]
        ye = PossibleColums[randrange(10)]
        
    sns.relplot(data=df, x = xe, y = ye, kind="scatter")

# %%
df["CasesGroup"] = pd.cut(
    df["TotCases1Mpop"],
    bins =[100000, 200000, 300000, 400000, 500000, 600000, 700000,maximize ],
    labels = ["<100K","<200K","<300K","<400K","<500K","<600K","<700K"]
)

sns.barplot(data= df, x = "CasesGroup", y="SeriousCritical")
# Out:
# ---------------------------------------------------
# NameError         Traceback (most recent call last)
# Cell In [20], line 3
#       1 df["CasesGroup"] = pd.cut(
#       2     df["TotCases1Mpop"],
# ----> 3     bins =[100000, 200000, 300000, 400000, 500000, 600000, 700000,maximize ],
#       4     labels = ["<100K","<200K","<300K","<400K","<500K","<600K","<700K"]
#       5 )
#       7 sns.barplot(data= df, x = "CasesGroup", y="SeriousCritical")
#
# NameError: name 'maximize' is not defined

# %%
correlations = df.corr()
sns.heatmap(correlations)
# Out:
# C:\Users\Basti\AppData\Local\Temp\ipykernel_7484\3340477437.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr()
# <AxesSubplot: >
